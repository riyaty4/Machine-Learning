# %% [markdown]
# # Matplotlib is a python library used to data visualization

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x = np.arange(100,10000)

# %%
x
# Out:
# array([ 100,  101,  102, ..., 9997, 9998, 9999])

# %%
y = 5 * x

# %%
y
# Out:
# array([  500,   505,   510, ..., 49985, 49990, 49995])

# %%
plt.plot (x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title('Line Plot')
plt.xlabel('X - Label')
plt.ylabel('Y - Label')
plt.show()

# %%
plt.plot(x,y,color='g',linestyle='--',linewidth=5)
plt.title('Line Plot')
plt.xlabel('X - Label')
plt.ylabel('Y - Label')
plt.show()

# %%
a = np.arange(10,100)
b1 = 2*a
b2 = 3*a

# %%
plt.plot(a,b1,color='g',linestyle='--',linewidth=1)
plt.plot(a,b2,color='b',linestyle=':',linewidth=3)
plt.title('Line Plot')
plt.xlabel('X - Label')
plt.ylabel('Y - Label')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(a,b1,color='g',linestyle='--',linewidth=1)

plt.subplot(1,2,2)
plt.plot(a,b2,color='g',linestyle='--',linewidth=1)

# %%
student = {'Bob':87, 'Matt':23, 'Sam':56}
names = list(student.keys())
values = list(student.values())
plt.bar(names,values)
plt.title('Bar Plot')
plt.xlabel('Names')
plt.ylabel('Marks')
plt.grid(True)

# %%
plt.barh(names,values,color='g')
# Out:
# <BarContainer object of 3 artists>

# %%
x = [10,20,30,40,50,60,70]
a = [4,6,2,9,5,1,8]
plt.scatter(x,a,)

# %%
x = [10,20,30,40,50,60,70]
a = [4,6,2,9,5,1,8]
plt.scatter(x,a,marker='*',c='g',s=200)

# %%
x = [10,20,30,40,50,60,70]
a = [4,6,2,9,5,1,8]
plt.scatter(x,a,marker='*',c='g',s=200)
